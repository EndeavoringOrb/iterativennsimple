# %%
# Imports
import torch.nn as nn
from testSeq2D import benchmarkModel
from IPython.display import display, Markdown

# %%
n_iters=1000
n_batch=512

# %%
# Wide Linear Model
display(Markdown("## 🧪 Testing Wide Linear Model"))
model = nn.Sequential(nn.Linear(2, 1024), nn.ReLU(), nn.Linear(1024, 1))
benchmarkModel(model, (2,), n_iters=n_iters, n_batch=n_batch, visualize=True)
# Out:
# ## 🧪 Testing Wide Linear Model
# [Base] Elapsed time: 0.311730 seconds
# {'total_matrix_size': 1054729, 'base_trainable_params': 4097, 'base_non_trainable_params': 0, 'added_trainable_params': 0, 'added_non_trainable_params': 0}
# [Seq2D] Elapsed time: 3.826559 seconds
# {'total_matrix_size': 1054729, 'base_trainable_params': 4097, 'base_non_trainable_params': 0, 'added_trainable_params': 0, 'added_non_trainable_params': 0, 'sparse_efficiency': '0/1054729 (0.00%)'}
# [Seq2DSparse] Elapsed time: 0.916743 seconds
# [Seq2DSparse Compiled] Elapsed time: 0.855421 seconds

# %%
# Wide Linear Model + Extra Blocks
display(Markdown("## ➕ Testing Wide Linear Model with Extra Connections"))
benchmarkModel(
    model,
    (2,),
    n_iters=n_iters,
    n_batch=n_batch,
    additional_blocks=[(2, 60, 40, 40), (0, 1026, 2, 1)],
    visualize=True,
)
# Out:
# ## ➕ Testing Wide Linear Model with Extra Connections
# [Base] Elapsed time: 0.397852 seconds
# {'total_matrix_size': 1054729, 'base_trainable_params': 4097, 'base_non_trainable_params': 0, 'added_trainable_params': 1602, 'added_non_trainable_params': 0}
# [Seq2D] Elapsed time: 3.553764 seconds
# {'total_matrix_size': 1054729, 'base_trainable_params': 4097, 'base_non_trainable_params': 0, 'added_trainable_params': 1602, 'added_non_trainable_params': 0, 'sparse_efficiency': '1602/1054729 (0.15%)'}
# [Seq2DSparse] Elapsed time: 0.962913 seconds
# [Seq2DSparse Compiled] Elapsed time: 0.961967 seconds

# %%
# Cell 5: Deep Linear Model
display(Markdown("## 🧪 Testing Deep Linear Model"))
model = nn.Sequential(
    nn.Linear(2, 16),
    nn.ReLU(),
    nn.Linear(16, 16),
    nn.ReLU(),
    nn.Linear(16, 16),
    nn.ReLU(),
    nn.Linear(16, 16),
    nn.ReLU(),
    nn.Linear(16, 16),
    nn.ReLU(),
    nn.Linear(16, 16),
    nn.ReLU(),
    nn.Linear(16, 16),
    nn.ReLU(),
    nn.Linear(16, 16),
    nn.ReLU(),
    nn.Linear(16, 16),
    nn.ReLU(),
    nn.Linear(16, 1),
)
benchmarkModel(model, (2,), n_iters=n_iters, n_batch=n_batch, visualize=True)
# Out:
# ## 🧪 Testing Deep Linear Model
# [Base] Elapsed time: 0.856735 seconds
# {'total_matrix_size': 21609, 'base_trainable_params': 2241, 'base_non_trainable_params': 0, 'added_trainable_params': 0, 'added_non_trainable_params': 0}
# [Seq2D] Elapsed time: 3.212132 seconds
# {'total_matrix_size': 21609, 'base_trainable_params': 2241, 'base_non_trainable_params': 0, 'added_trainable_params': 0, 'added_non_trainable_params': 0, 'sparse_efficiency': '0/21609 (0.00%)'}
# [Seq2DSparse] Elapsed time: 1.499061 seconds
# [Seq2DSparse Compiled] Elapsed time: 1.386921 seconds

# %%
# Cell 6: Conv2D Model
display(Markdown("## 🧪 Testing Conv2D Model"))
model = nn.Sequential(
    nn.Conv2d(1, 3, 3, padding=1),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(3 * 4 * 4, 1),
)
benchmarkModel(model, (1, 1, 4, 4), n_iters=n_iters, n_batch=n_batch, visualize=True)
# Out:
# ## 🧪 Testing Conv2D Model
# [Base] Elapsed time: 0.348387 seconds
# {'total_matrix_size': 4225, 'base_trainable_params': 79, 'base_non_trainable_params': 0, 'added_trainable_params': 0, 'added_non_trainable_params': 0}
# [Seq2D] Elapsed time: 0.640665 seconds
# {'total_matrix_size': 4225, 'base_trainable_params': 79, 'base_non_trainable_params': 0, 'added_trainable_params': 0, 'added_non_trainable_params': 0, 'sparse_efficiency': '0/4225 (0.00%)'}
# [Seq2DSparse] Elapsed time: 0.606543 seconds
# [Seq2DSparse Compiled] Elapsed time: 0.645940 seconds
